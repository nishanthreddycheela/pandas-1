# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("universities.csv")
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %% [markdown]
# jkkehi

# %%
df.sort_values(by='Top10',ascending = True)
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 15        Purdue  1005     28      90       19      9066        69
# 13     PennState  1081     38      54       18     10185        80
# 23    UWisconsin  1085     40      69       15     11857        71
# 17      TexasA&M  1075     49      67       25      8704        67
# 2            CMU  1260     62      59        9     25026        72
# 20     UMichigan  1180     65      68       16     15470        85
# 7     Georgetown  1255     74      24       12     20126        92
# 19      UChicago  1290     75      50       13     38380        87
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 3       Columbia  1310     76      24       12     31510        88
# 22           UVA  1225     77      44       14     13349        92
# 21         UPenn  1285     80      36       11     27553        90
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
df[df["GradRate"]>=95]
# Out:
#          Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 5   Dartmouth  1340     89      23       10     32162        95
# 6        Duke  1315     90      30       12     31585        95
# 8     Harvard  1400     91      14       11     39525        97
# 14  Princeton  1375     91      14        8     30220        95
# 24       Yale  1375     95      19       11     43514        96

# %%
df[(df["GradRate"]>=80) & (df["SFRatio"]<=12)]
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 1        CalTech  1415    100      25        6     63575        81
# 3       Columbia  1310     76      24       12     31510        88
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 14     Princeton  1375     91      14        8     30220        95
# 16      Stanford  1360     90      20       12     36450        93
# 21         UPenn  1285     80      36       11     27553        90
# 24          Yale  1375     95      19       11     43514        96

# %%
sal = pd.read_csv("Salaries.csv")
sal
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   20       20    Male  122400
# 2   AssocProf          A   20       17    Male   81285
# 3        Prof          B   23       23    Male  134778
# 4    AsstProf          B    1        0    Male   88000
# 5        Prof          B   17        3    Male  150480
# 6    AsstProf          B    8        3    Male   75044
# 7    AsstProf          B    4        0    Male   92000
# 8        Prof          A   19        7    Male  107300
# 9        Prof          A   29       27    Male  150500
# 10   AsstProf          B    4        4    Male   92000
# 11       Prof          A   33       30    Male  103106
# 12   AsstProf          A    4        2    Male   73000
# 13   AsstProf          A    2        0    Male   85000
# 14       Prof          A   30       23    Male   91100
# 15   AsstProf          B    7        2    Male   91300
# ...

# %%
sal[["salary","phd","service"]].groupby(sal["rank"]).mean()
# Out:
#                   salary        phd    service
# rank
# AssocProf   93270.777778  14.888889  11.111111
# AsstProf    82260.500000   5.312500   2.500000
# Prof       125561.615385  26.307692  20.038462

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Universities.csv")
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
np.var(df["SFRatio"])
# Out:
# 15.881599999999999

# %%
df.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %% [markdown]
# # visualization

# %%
# visualization the GradRate using historic
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6,3))
plt.title("Graduation Rate")
plt.hist(df["GradRate"])
# Out:
# (array([2., 2., 0., 1., 2., 0., 3., 4., 4., 7.]),
#  array([67., 70., 73., 76., 79., 82., 85., 88., 91., 94., 97.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # visualization using box plot

# %%
s = [20,15,10,25,30,35,28,40,45,60]
scores = pd.Series(s)
scores
# Out:
# 0    20
# 1    15
# 2    10
# 3    25
# 4    30
# 5    35
# 6    28
# 7    40
# 8    45
# 9    60
# dtype: int64

# %%
plt.boxplot(scores)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12ba3492ba0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12ba34930b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12ba34928d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x12ba3493500>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12ba3493800>],
#  'means': []}

# %%
s = [20,15,10,25,30,35,28,40,45,60,120,150]
scores = pd.Series(s)
scores
# Out:
# 0      20
# 1      15
# 2      10
# 3      25
# 4      30
# 5      35
# 6      28
# 7      40
# 8      45
# 9      60
# 10    120
# 11    150
# dtype: int64

# %%
plt.boxplot(scores, vert="False")
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12ba352fc20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12ba35303e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12ba352f950>],
#  'medians': [<matplotlib.lines.Line2D at 0x12ba3530890>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12ba3530bc0>],
#  'means': []}

# %% [markdown]
# # visualization of data from universite data set

# %%
df= pd.read_csv("universities.csv")
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
import matplotlib.pyplot as plt

plt.boxplot([df['SAT'], df['Top10'], df['Accept'], df['SFRatio'], df['Expenses'], df['GradRate']], vert=False)
plt.show()

# %%
plt.title("Box plot for SAT Score")
plt.boxplot(df["SAT"], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12ba4bafd10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12ba5229d30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12ba5229610>],
#  'medians': [<matplotlib.lines.Line2D at 0x12ba522a180>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12ba522a3c0>],
#  'means': []}

# %%
plt.title("Box plot for SAT Score")
plt.boxplot(df["Top10"], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12ba56138c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12ba5613b60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12ba5613650>],
#  'medians': [<matplotlib.lines.Line2D at 0x12ba5620200>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12ba56204d0>],
#  'means': []}
